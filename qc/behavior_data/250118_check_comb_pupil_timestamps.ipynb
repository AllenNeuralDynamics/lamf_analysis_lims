# %% [markdown]
# # Purpose:
# - Checking timestamps of pupil table from COMB (still in dev, waiting confirmation for merging)

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from brain_observatory_qc.data_access import from_lims
from visual_behavior.data_access import loading
import matplotlib.pyplot as plt
import h5py
# Out:
# c:\Users\jinho.kim\Anaconda3\envs\allenvisb\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\jinho.kim\Anaconda3\envs\allenvisb\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# c:\Users\jinho.kim\Anaconda3\envs\allenvisb\lib\site-packages\numpy\.libs\libopenblas.gk7gx5keq4f6uyo3p26ulgbqyhgqo7j4.gfortran-win_amd64.dll
# c:\Users\jinho.kim\Anaconda3\envs\allenvisb\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
osid = 1386564013 # 736963_2024-08-13
osid = 1382209121 # 736963_2024-07-24

# %%
oeids = from_lims.get_ophys_experiment_ids_for_ophys_session_id(osid).ophys_experiment_id.values
dataset = loading.get_ophys_dataset(oeids[0], get_extended_stimulus_presentations=True,
                                                    get_behavior_movie_timestamps=True)

dataset.eye_tracking
# Out:
# loading from lims, exclude_invalid_rois = True
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 oeids = from_lims.get_ophys_experiment_ids_for_ophys_session_id(osid).ophys_experiment_id.values
# ----> 2 dataset = loading.get_ophys_dataset(oeids[0], get_extended_stimulus_presentations=True,
#       3                                                     get_behavior_movie_timestamps=True)
#       5 dataset.eye_tracking
#
# File ~\Github\visual_behavior_analysis\visual_behavior\data_access\loading.py:845, in get_ophys_dataset(ophys_experiment_id, exclude_invalid_rois, load_from_lims, load_from_nwb, get_extended_stimulus_presentations, get_behavior_movie_timestamps)
#     842     print('loading from lims, exclude_invalid_rois =', exclude_invalid_rois)
#     843     # cache = bpc.from_lims()
# ...

# %%
from allensdk.brain_observatory.behavior.behavior_project_cache import VisualBehaviorOphysProjectCache as bpc
from allensdk.brain_observatory.behavior.behavior_ophys_experiment import BehaviorOphysExperiment

# %%
oeid = oeids[0]
exp = BehaviorOphysExperiment.from_lims(oeid)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 oeid = oeids[0]
# ----> 2 exp = BehaviorOphysExperiment.from_lims(oeid)
#
# File c:\users\jinho.kim\github\allensdk\allensdk\brain_observatory\behavior\behavior_ophys_experiment.py:150, in BehaviorOphysExperiment.from_lims(cls, ophys_experiment_id, eye_tracking_z_threshold, eye_tracking_dilation_frames, events_filter_scale_seconds, events_filter_n_time_steps, exclude_invalid_rois, skip_eye_tracking)
#     143 is_multiplane_session = _is_multi_plane_session()
#     145 meta = BehaviorOphysMetadata.from_lims(
#     146     ophys_experiment_id=ophys_experiment_id, lims_db=lims_db,
#     147     is_multiplane=is_multiplane_session
#     148 )
# --> 150 sync_file = SyncFile.from_lims(
#     151     db=lims_db,
#     152     behavior_session_id=behavior_session_id.value)
# ...
