# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt
import napari
from pathlib import Path

# %%
print(Path('/allen/programs/mindscope/production/learning/prod2/0534355451-0046_1405961756/'))
# Out:
# \allen\programs\mindscope\production\learning\prod2\0534355451-0046_1405961756

# %%
fn = r"\\allen\programs\mindscope\production\learning\prod2\0534355451-0046_1405961756\0534355451-0046.jp2"
with rasterio.open(fn) as src:
    img = src.read()
# Out:
# c:\Users\jinho.kim\Anaconda3\envs\napari-suite2p\lib\site-packages\rasterio\__init__.py:386: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %%
img.shape
# Out:
# (3, 30000, 40000)

# %%
type(img[1,0,0])
# Out:
# numpy.uint16

# %%
vmax = 5000
fig, ax = plt.subplots()
ax.hist(img[0].flatten(), bins=np.arange(50, vmax, 10), alpha=0.5, color='m', label='red');
ax.hist(img[1].flatten(), bins=np.arange(50, vmax, 10), alpha=0.5, color='g', label='green');
ax.legend()
ax.set_xlabel('Pixel value')
# Out:
# Text(0.5, 0, 'Pixel value')

# %%
vmax = 30000
fig, ax = plt.subplots()
ax.hist(img[0].flatten(), bins=np.arange(50, vmax, 10), alpha=0.5, color='m', label='red');
ax.hist(img[1].flatten(), bins=np.arange(50, vmax, 10), alpha=0.5, color='g', label='green');
ax.legend()
ax.set_xlabel('Pixel value')
ax.set_ylim(0, 10000)
# Out:
# (0.0, 10000.0)

# %%
plt.imshow(img[1], vmax=vmax)

# %%
y1 = 4500
y2 = y1 + 2100
x1 = 23000
x2 = x1 + 2100
plt.imshow(img[1][y1:y2, x1:x2], vmax=5000)

# %%
fig, ax = plt.subplots()
ax.hist(img[1][y1:y2, x1:x2].flatten(), bins=np.arange(50, 20000, 10));
ax.set_ylim(0, 1000)
# Out:
# (0.0, 1000.0)

# %%
img[1][y1:y2, x1:x2].max()
# Out:
# 18092

# %%
2**14
# Out:
# 16384

# %%
counts, bins = np.histogram(img[1][y1:y2, x1:x2], bins=np.arange(7500, 20000, 10))
bins[np.argmax(counts)]
# Out:
# 14340

# %%
fn2 = r"\\allen\programs\mindscope\production\learning\prod2\0534355612-0048_1401029588\0534355612-0048.jp2"
with rasterio.open(fn2) as src:
    img2 = src.read()
# Out:
# c:\Users\jinho.kim\Anaconda3\envs\napari-suite2p\lib\site-packages\rasterio\__init__.py:386: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %%
from cellpose import io, models

# %%
plt.imshow(img[1][y1:y2, x1:x2])

# %%
masks, flows, styles = models.CellposeModel(model_type='cyto2').eval(img[1][y1:y2, x1:x2],
                            diameter=0)

# %%
from skimage import measure

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(img[1][y1:y2, x1:x2], cmap='gray')
for i in range(1, masks.max()+1):
    mask = masks == i
    contours = measure.find_contours(mask, 0.5)
    for contour in contours:
        ax.plot(contour[:, 1], contour[:, 0], linewidth=0.5, color='r')

# %%
y1 = 1200
y2 = y1 + 700
x1 = 3500
x2 = x1 + 700
plt.imshow(img2[1][y1:y2, x1:x2], vmax=2000)

# %%
masks, flows, styles = models.CellposeModel(model_type='cyto2').eval(img2[1][y1:y2, x1:x2],
                            diameter=0)
# Out:
# c:\Users\jinho.kim\Anaconda3\envs\napari-suite2p\lib\site-packages\cellpose\resnet_torch.py:280: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(img2[1][y1:y2, x1:x2], cmap='gray')
for i in range(1, masks.max()+1):
    mask = masks == i
    contours = measure.find_contours(mask, 0.5)
    for contour in contours:
        ax.plot(contour[:, 1], contour[:, 0], linewidth=0.5, color='r')

# %%
viewer = napari.Viewer()
viewer.add_image(img[1], name='img')
# Out:
# WARNING: WARNING: QApplication was not created in the main() thread.
# <Image layer 'img' at 0x2a814a53b50>

# %%
print(Path('/allen/programs/mindscope/production/learning/prod2/0534356003-0047_1405709012/'))
# Out:
# \allen\programs\mindscope\production\learning\prod2\0534356003-0047_1405709012

# %%
fn = r"\\allen\programs\mindscope\production\learning\prod2\0534356003-0047_1405709012\0534356003-0047.jp2"
with rasterio.open(fn) as src:
    img_759534 = src.read()
# Out:
# c:\Users\jinho.kim\Anaconda3\envs\napari-suite2p\lib\site-packages\rasterio\__init__.py:386: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %%
vmax = 5000
fig, ax = plt.subplots()
ax.hist(img_759534[0].flatten(), bins=np.arange(50, vmax, 10), alpha=0.5, color='m', label='red');
ax.hist(img_759534[1].flatten(), bins=np.arange(50, vmax, 10), alpha=0.5, color='g', label='green');
ax.legend()
ax.set_xlabel('Pixel value')
# Out:
# Text(0.5, 0, 'Pixel value')

# %%
vmax = 30000
fig, ax = plt.subplots()
ax.hist(img_759534[0].flatten(), bins=np.arange(50, vmax, 10), alpha=0.5, color='m', label='red');
ax.hist(img_759534[1].flatten(), bins=np.arange(50, vmax, 10), alpha=0.5, color='g', label='green');
ax.legend()
ax.set_xlabel('Pixel value')
ax.set_ylim(0, 10000)
# Out:
# (0.0, 10000.0)

# %%
vmax = 5000
plt.imshow(img_759534[1], vmax=vmax)

# %%
y1 = 4300
y2 = y1 + 2100
x1 = 10000
x2 = x1 + 2100
plt.imshow(img_759534[1][y1:y2, x1:x2], vmax=5000)

# %%
fig, ax = plt.subplots()
ax.hist(img_759534[1][y1:y2, x1:x2].flatten(), bins=np.arange(50, 20000, 10));
ax.set_ylim(0, 300)
# Out:
# (0.0, 300.0)

# %%
fig, ax = plt.subplots()
ax.hist(img_759534[1][y1:y2, x1:x2].flatten(), bins=np.arange(50, 20000, 10));
ax.set_ylim(0, 50)
ax.set_xlim(16200, 16600)
# Out:
# (16200.0, 16600.0)

# %%
2**14
# Out:
# 16384

# %% [markdown]
# # Save the parts from Slc32a1;Oi1
# - to Tiff files

# %%
output_dir = Path(r'\\allen\programs\mindscope\workgroups\learning\pilots\GCaMP8\TissueCyte')

# %%
import tifffile

# %%
y1 = 4000
y2 = y1 + 2100
x1 = 10000
x2 = x1 + 2100
temp_im = img[1][y1:y2, x1:x2]
save_fn = output_dir / '759529_v1_left.tif'
tifffile.imsave(save_fn, temp_im)

# %%
y1 = 4500
y2 = y1 + 2100
x1 = 23000
x2 = x1 + 2100
temp_im = img[1][y1:y2, x1:x2]
save_fn = output_dir / '759529_v1_right.tif'
tifffile.imsave(save_fn, temp_im)
# Out:
# C:\Users\jinho.kim\AppData\Local\Temp\ipykernel_28248\1094411686.py:7: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tifffile.imsave(save_fn, temp_im)

# %%
y1 = 4300
y2 = y1 + 2100
x1 = 10000
x2 = x1 + 2100
temp_im = img_759534[1][y1:y2, x1:x2]
save_fn = output_dir / '759534_v1_left.tif'
tifffile.imsave(save_fn, temp_im)
# Out:
# C:\Users\jinho.kim\AppData\Local\Temp\ipykernel_28248\379906984.py:7: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tifffile.imsave(save_fn, temp_im)

# %%
y1 = 4700
y2 = y1 + 2100
x1 = 23000
x2 = x1 + 2100
temp_im = img_759534[1][y1:y2, x1:x2]
save_fn = output_dir / '759534_v1_right.tif'
tifffile.imsave(save_fn, temp_im)
# Out:
# C:\Users\jinho.kim\AppData\Local\Temp\ipykernel_28248\2499108862.py:7: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tifffile.imsave(save_fn, temp_im)
