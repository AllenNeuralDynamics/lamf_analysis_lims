# %% [markdown]
# # Purpose:
# - Check tif results

# %%
from tifffile import imread
import napari
import numpy as np
from pathlib import Path

viewer = napari.Viewer()

# %%
raw_fns = [r"\\meso2acq\D\scanimage_ophys\data\1431960307\1431960307_local_z_stack3.tiff",
           r"\\meso2acq\D\scanimage_ophys\data\1431960307\1431960307_local_z_stack0.tiff",
           r"\\meso2acq\D\scanimage_ophys\data\1431960307\1431960307_local_z_stack1.tiff",
           r"\\meso2acq\D\scanimage_ophys\data\1431960307\1431960307_local_z_stack2.tiff"]

split_fns = [r"\\meso2acq\D\scanimage_ophys\data\1431960307\sorted_local_z_stacks\1431960307_local_z_stack1_reg_ch_2.tif",
             r"\\meso2acq\D\scanimage_ophys\data\1431960307\sorted_local_z_stacks\1431960307_local_z_stack2_reg_ch_1.tif",
             r"\\meso2acq\D\scanimage_ophys\data\1431960307\sorted_local_z_stacks\1431960307_local_z_stack2_reg_ch_2.tif",
             r"\\meso2acq\D\scanimage_ophys\data\1431960307\sorted_local_z_stacks\1431960307_local_z_stack3_reg_ch_1.tif",
             r"\\meso2acq\D\scanimage_ophys\data\1431960307\sorted_local_z_stacks\1431960307_local_z_stack3_reg_ch_2.tif",
             r"\\meso2acq\D\scanimage_ophys\data\1431960307\sorted_local_z_stacks\1431960307_local_z_stack0_reg_ch_1.tif",
             r"\\meso2acq\D\scanimage_ophys\data\1431960307\sorted_local_z_stacks\1431960307_local_z_stack0_reg_ch_2.tif",
             r"\\meso2acq\D\scanimage_ophys\data\1431960307\sorted_local_z_stacks\1431960307_local_z_stack1_reg_ch_1.tif"]
my_output_dir = Path(r'\\allen\programs\mindscope\workgroups\learning\pilots\online_motion_correction\sipe_test\1431960307')

# %%
# read a header from one of the raw files
raw_fn = raw_fns[3]
raw_data = imread(raw_fn)

# %%
ch1_raw = np.squeeze(raw_data[:,0,:,:])
ch2_raw = np.squeeze(raw_data[:,1,:,:])
ch1_mean = np.zeros((81,512,512))
ch2_mean = np.zeros((81,512,512))
for i in range(81):
    ch1_mean[i] = np.mean(ch1_raw[i::81], axis=0)
    ch2_mean[i] = np.mean(ch2_raw[i::81], axis=0)

ch1_reg = imread(r"\\meso2acq\D\scanimage_ophys\data\1431960307\sorted_local_z_stacks\1431960307_local_z_stack2_reg_ch_1.tif")
ch2_reg = imread(r"\\meso2acq\D\scanimage_ophys\data\1431960307\sorted_local_z_stacks\1431960307_local_z_stack2_reg_ch_2.tif")

ch1_my_reg = imread(my_output_dir / "1431960307_local_z_stack2_reg_ch_1.tif")
ch2_my_reg = imread(my_output_dir / "1431960307_local_z_stack2_reg_ch_2.tif")

# %%
viewer = napari.Viewer()
viewer.add_image(ch1_mean)
viewer.add_image(ch1_reg)
viewer.add_image(ch1_my_reg)
viewer.add_image(ch2_mean)
viewer.add_image(ch2_reg)
viewer.add_image(ch2_my_reg)
# Out:
# <Image layer 'ch2_my_reg' at 0x18160991190>

# %%
split_fns = [r"\\meso2acq\D\scanimage_ophys\data\1431960307\sorted_local_z_stacks\1431960307_local_z_stack1_reg_ch_2.tif",
             r"\\meso2acq\D\scanimage_ophys\data\1431960307\sorted_local_z_stacks\1431960307_local_z_stack2_reg_ch_1.tif",
             r"\\meso2acq\D\scanimage_ophys\data\1431960307\sorted_local_z_stacks\1431960307_local_z_stack2_reg_ch_2.tif",
             r"\\meso2acq\D\scanimage_ophys\data\1431960307\sorted_local_z_stacks\1431960307_local_z_stack3_reg_ch_1.tif",
             r"\\meso2acq\D\scanimage_ophys\data\1431960307\sorted_local_z_stacks\1431960307_local_z_stack3_reg_ch_2.tif",
             r"\\meso2acq\D\scanimage_ophys\data\1431960307\sorted_local_z_stacks\1431960307_local_z_stack0_reg_ch_1.tif",
             r"\\meso2acq\D\scanimage_ophys\data\1431960307\sorted_local_z_stacks\1431960307_local_z_stack0_reg_ch_2.tif",
             r"\\meso2acq\D\scanimage_ophys\data\1431960307\sorted_local_z_stacks\1431960307_local_z_stack1_reg_ch_1.tif"]
test_fn = [r"C:\temp\local_zstack_test\1431960307_local_z_stack1_reg_ch_2.tif",
            r"C:\temp\local_zstack_test\1431960307_local_z_stack2_reg_ch_1.tif",
            r"C:\temp\local_zstack_test\1431960307_local_z_stack2_reg_ch_2.tif",
            r"C:\temp\local_zstack_test\1431960307_local_z_stack3_reg_ch_1.tif",
            r"C:\temp\local_zstack_test\1431960307_local_z_stack3_reg_ch_2.tif",
            r"C:\temp\local_zstack_test\1431960307_local_z_stack0_reg_ch_1.tif",
            r"C:\temp\local_zstack_test\1431960307_local_z_stack0_reg_ch_2.tif",
            r"C:\temp\local_zstack_test\1431960307_local_z_stack1_reg_ch_1.tif"]

# %%
for ind in range(8):
    sf = imread(split_fns[ind])
    tf = imread(test_fn[ind])
    print(np.array_equal(sf, tf))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
